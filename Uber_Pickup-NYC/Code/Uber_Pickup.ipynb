# %% [markdown]
# Group project
#
# NIKHIL KRISHNA A R, ME20BTECH11031
#
# DEVANANTH V, EP20BTECH11004

# %%
import scipy as sc
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb
import folium 
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar 
from sklearn.cluster import KMeans 
from yellowbrick.cluster import KElbowVisualizer 
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# %%
df=pd.read_csv("../Data/uber-raw-data-apr14.csv")
type(df.loc[0,'Date/Time'])
df['Date/Time'] = pd.to_datetime(df['Date/Time'])
type(df.loc[0,'Date/Time'])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# REARRANGING THE DATA

# %%
df['BinnedHour']=df['Date/Time'].dt.floor('15min')
df['BinnedHour']
# Out:
# 0        2014-04-01 00:00:00
# 1        2014-04-01 00:15:00
# 2        2014-04-01 00:15:00
# 3        2014-04-01 00:15:00
# 4        2014-04-01 00:30:00
#                  ...
# 564511   2014-04-30 23:15:00
# 564512   2014-04-30 23:15:00
# 564513   2014-04-30 23:30:00
# 564514   2014-04-30 23:30:00
# 564515   2014-04-30 23:45:00
# Name: BinnedHour, Length: 564516, dtype: datetime64[ns]

# %%
plt.figure(figsize=(15,8))
df['BinnedHour'].dt.day.value_counts().sort_index().plot(kind='bar',color='green')
plt.title('Uber Rides per day in April 2014 at NYC')
plt.xlabel('Days')
plt.ylabel('Rides')
# Out:
# Text(0, 0.5, 'Rides')

# %%
DayMap={0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}
df['Day']=df['BinnedHour'].dt.weekday.map(DayMap)
df['Date']=df['BinnedHour'].dt.date
df['Day']=pd.Categorical(df['Day'],categories=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'],ordered=True)
df['Time']=df['BinnedHour'].dt.time

# %%
weekly_data = df.groupby(['Date','Day','Time']).count().dropna().rename(columns={'BinnedHour':'Rides'})['Rides'].reset_index()
weekly_data.head(10)
# Out:
#          Date     Day      Time  Rides
# 0  2014-04-01  Monday  00:00:00      0
# 1  2014-04-01  Monday  00:15:00      0
# 2  2014-04-01  Monday  00:30:00      0
# 3  2014-04-01  Monday  00:45:00      0
# 4  2014-04-01  Monday  01:00:00      0
# 5  2014-04-01  Monday  01:15:00      0
# 6  2014-04-01  Monday  01:30:00      0
# 7  2014-04-01  Monday  01:45:00      0
# 8  2014-04-01  Monday  02:00:00      0
# 9  2014-04-01  Monday  02:15:00      0

# %%
df.head(10)
# Out:
#             Date/Time      Lat      Lon    Base          BinnedHour      Day  \
# 0 2014-04-01 00:11:00  40.7690 -73.9549  B02512 2014-04-01 00:00:00  Tuesday
# 1 2014-04-01 00:17:00  40.7267 -74.0345  B02512 2014-04-01 00:15:00  Tuesday
# 2 2014-04-01 00:21:00  40.7316 -73.9873  B02512 2014-04-01 00:15:00  Tuesday
# 3 2014-04-01 00:28:00  40.7588 -73.9776  B02512 2014-04-01 00:15:00  Tuesday
# 4 2014-04-01 00:33:00  40.7594 -73.9722  B02512 2014-04-01 00:30:00  Tuesday
# 5 2014-04-01 00:33:00  40.7383 -74.0403  B02512 2014-04-01 00:30:00  Tuesday
# 6 2014-04-01 00:39:00  40.7223 -73.9887  B02512 2014-04-01 00:30:00  Tuesday
# 7 2014-04-01 00:45:00  40.7620 -73.9790  B02512 2014-04-01 00:45:00  Tuesday
# 8 2014-04-01 00:55:00  40.7524 -73.9960  B02512 2014-04-01 00:45:00  Tuesday
# 9 2014-04-01 01:01:00  40.7575 -73.9846  B02512 2014-04-01 01:00:00  Tuesday
#
#          Date      Time
# 0  2014-04-01  00:00:00
# 1  2014-04-01  00:15:00
# 2  2014-04-01  00:15:00
# 3  2014-04-01  00:15:00
# 4  2014-04-01  00:30:00
# 5  2014-04-01  00:30:00
# 6  2014-04-01  00:30:00
# 7  2014-04-01  00:45:00
# 8  2014-04-01  00:45:00
# 9  2014-04-01  01:00:00

# %% [markdown]
# APPLYING K MEANS CLUSTERING ON THE DATA

# %%
clus_k_ori = df[['Lat', 'Lon']] #defining an object class for latititude ang longitude values
clus_k_ori.dtypes
# Out:
# Lat    float64
# Lon    float64
# dtype: object

# %%
model_ori = KMeans(n_init = 'auto') 
visualizer = KElbowVisualizer(model_ori, k = (1, 20)) #k = 1 to 19
visualizer.fit(clus_k_ori) #finding the optimal no of clusters elbow method
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans_ori = KMeans(n_clusters = 6, random_state = 0, n_init = 'auto') #k = 6
kmeans_ori.fit(clus_k_ori)# k means of the data
# Out:
# KMeans(n_clusters=6, n_init='auto', random_state=0)

# %%
centroids_k_ori = kmeans_ori.cluster_centers_
centroids_k_ori
#values of the centroids of the clusters
# Out:
# array([[ 40.73116126, -73.99859286],
#        [ 40.68861777, -73.96557249],
#        [ 40.65950667, -73.77405861],
#        [ 40.7005414 , -74.20167303],
#        [ 40.76559459, -73.97279011],
#        [ 40.79804315, -73.86868047]])

# %%
clocation_k_ori = pd.DataFrame(centroids_k_ori, columns = ['Latitude', 'Longitude'])
clocation_k_ori
# Out:
#     Latitude  Longitude
# 0  40.731161 -73.998593
# 1  40.688618 -73.965572
# 2  40.659507 -73.774059
# 3  40.700541 -74.201673
# 4  40.765595 -73.972790
# 5  40.798043 -73.868680

# %%
plt.scatter(clocation_k_ori['Longitude'],clocation_k_ori['Latitude'],  marker = "x", color = 'r', s = 200)
#ploting the location of centroids

# %%
centroid_k_ori = clocation_k_ori.values.tolist()

map_k_ori = folium.Map(location = [40.71600413400166, -73.98971408426613], zoom_start = 10)
for point in range(0, len(centroid_k_ori)):
    folium.Marker(centroid_k_ori[point], popup = centroid_k_ori[point]).add_to(map_k_ori)

map_k_ori
#showing the centroids location in map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2929c9b7e868d984c0789920e5a09d65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2929c9b7e868d984c0789920e5a09d65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2929c9b7e868d984c0789920e5a09d65 = L.map(
#                 &quot;map_2929c9b7e868d984c0789920e5a09d65&quot;,
#                 {
#                     center: [40.71600413400166, -73.98971408426613],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c2d186a15911dd124be5e9ffab65c99 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2929c9b7e868d984c0789920e5a09d65);
#
#
#             var marker_9d0e02e7e931ca83b9fac2bc76004e75 = L.marker(
#                 [40.73116125598914, -73.99859285825791],
#                 {}
#             ).addTo(map_2929c9b7e868d984c0789920e5a09d65);
#
#
#         var popup_9dfa6f6a497f7e2a16190cbc7ea8c710 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87c5917ec151213e3e5e444f563a14b9 = $(`&lt;div id=&quot;html_87c5917ec151213e3e5e444f563a14b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.73116125598914, -73.99859285825791]&lt;/div&gt;`)[0];
#                 popup_9dfa6f6a497f7e2a16190cbc7ea8c710.setContent(html_87c5917ec151213e3e5e444f563a14b9);
#
#
#
#         marker_9d0e02e7e931ca83b9fac2bc76004e75.bindPopup(popup_9dfa6f6a497f7e2a16190cbc7ea8c710)
#         ;
#
#
#
#
#             var marker_68de5f982e4b93f6465fae973fb0b92f = L.marker(
#                 [40.68861776959355, -73.9655724882097],
#                 {}
#             ).addTo(map_2929c9b7e868d984c0789920e5a09d65);
#
#
#         var popup_2514c85fc825001f04ba7256bb5e46de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_852405b457ebedc2cb50ac585038de2b = $(`&lt;div id=&quot;html_852405b457ebedc2cb50ac585038de2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.68861776959355, -73.9655724882097]&lt;/div&gt;`)[0];
#                 popup_2514c85fc825001f04ba7256bb5e46de.setContent(html_852405b457ebedc2cb50ac585038de2b);
#
#
#
#         marker_68de5f982e4b93f6465fae973fb0b92f.bindPopup(popup_2514c85fc825001f04ba7256bb5e46de)
#         ;
#
#
#
#
#             var marker_06a09c405bf4ed7acf15f538dbee701b = L.marker(
#                 [40.659506671757846, -73.7740586087198],
#                 {}
#             ).addTo(map_2929c9b7e868d984c0789920e5a09d65);
#
#
#         var popup_1f158e975bfd387f9bb875715b9fb4a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c35f8690ab1bd6f5e99f975b146d545 = $(`&lt;div id=&quot;html_0c35f8690ab1bd6f5e99f975b146d545&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.659506671757846, -73.7740586087198]&lt;/div&gt;`)[0];
#                 popup_1f158e975bfd387f9bb875715b9fb4a2.setContent(html_0c35f8690ab1bd6f5e99f975b146d545);
#
#
#
#         marker_06a09c405bf4ed7acf15f538dbee701b.bindPopup(popup_1f158e975bfd387f9bb875715b9fb4a2)
#         ;
#
#
#
#
#             var marker_2cd11da83a115e3168dcf031663fd450 = L.marker(
#                 [40.70054140415895, -74.20167302861849],
#                 {}
#             ).addTo(map_2929c9b7e868d984c0789920e5a09d65);
#
#
#         var popup_a74e9720d6d670675dea508e29e1ead6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_564132db20dee2a873c52cc098ba8687 = $(`&lt;div id=&quot;html_564132db20dee2a873c52cc098ba8687&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.70054140415895, -74.20167302861849]&lt;/div&gt;`)[0];
#                 popup_a74e9720d6d670675dea508e29e1ead6.setContent(html_564132db20dee2a873c52cc098ba8687);
#
#
#
#         marker_2cd11da83a115e3168dcf031663fd450.bindPopup(popup_a74e9720d6d670675dea508e29e1ead6)
#         ;
#
#
#
#
#             var marker_47500ffbaf398ddb6015ea5b3ae32d57 = L.marker(
#                 [40.76559459122114, -73.97279011256732],
#                 {}
#             ).addTo(map_2929c9b7e868d984c0789920e5a09d65);
#
#
#         var popup_07ae99cdaba2b1470356a3e4d94a7ec3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c320bb23ad8266a281b3f38c9f530fb7 = $(`&lt;div id=&quot;html_c320bb23ad8266a281b3f38c9f530fb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.76559459122114, -73.97279011256732]&lt;/div&gt;`)[0];
#                 popup_07ae99cdaba2b1470356a3e4d94a7ec3.setContent(html_c320bb23ad8266a281b3f38c9f530fb7);
#
#
#
#         marker_47500ff

# %%
label_k_ori = kmeans_ori.labels_
label_k_ori
# Out:
# array([4, 0, 0, ..., 0, 1, 1], dtype=int32)

# %%
df_new_k = df.copy()
df_new_k['Clusters'] = label_k_ori
df_new_k
#adding a row Clusters to show the cluster a point belongs to
# Out:
#                  Date/Time      Lat      Lon    Base          BinnedHour  \
# 0      2014-04-01 00:11:00  40.7690 -73.9549  B02512 2014-04-01 00:00:00
# 1      2014-04-01 00:17:00  40.7267 -74.0345  B02512 2014-04-01 00:15:00
# 2      2014-04-01 00:21:00  40.7316 -73.9873  B02512 2014-04-01 00:15:00
# 3      2014-04-01 00:28:00  40.7588 -73.9776  B02512 2014-04-01 00:15:00
# 4      2014-04-01 00:33:00  40.7594 -73.9722  B02512 2014-04-01 00:30:00
# ...                    ...      ...      ...     ...                 ...
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764 2014-04-30 23:15:00
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764 2014-04-30 23:15:00
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764 2014-04-30 23:30:00
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764 2014-04-30 23:30:00
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764 2014-04-30 23:45:00
#
#               Day        Date      Time  Clusters
# 0         Tuesday  2014-04-01  00:00:00         4
# 1         Tuesday  2014-04-01  00:15:00         0
# 2         Tuesday  2014-04-01  00:15:00         0
# 3         Tuesday  2014-04-01  00:15:00         4
# 4         Tuesday  2014-04-01  00:30:00         4
# ...           ...         ...       ...       ...
# 564511  Wednesday  2014-04-30  23:15:00         4
# 564512  Wednesday  2014-04-30  23:15:00         4
# 564513  Wednesday  2014-04-30  23:30:00         0
# 564514  Wednesday  2014-04-30  23:30:00         1
# 564515  Wednesday  2014-04-30  23:45:00         1
#
# [564516 rows x 9 columns]

# %%
#Getting unique labels
u_labels = np.unique(label_k_ori)
u_labels
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int32)

# %%
#array of cluster values
ymeans=np.copy(df_new_k['Clusters'] )
ymeans
# Out:
# array([4, 0, 0, ..., 0, 1, 1], dtype=int32)

# %%
df_new_k['Clusters']
# Out:
# 0         4
# 1         0
# 2         0
# 3         4
# 4         4
#          ..
# 564511    4
# 564512    4
# 564513    0
# 564514    1
# 564515    1
# Name: Clusters, Length: 564516, dtype: int32

# %%
#scatter plot of the clusters
fig,ax=plt.subplots()
ax.scatter( df['Lon'], df['Lat'],c=ymeans, s=50, cmap='viridis')
ax.set_xlabel("Longitude")
ax.set_ylabel("Lattitude")
plt.show()

# %% [markdown]
# no of pickups in different clusters

# %%
sb.catplot(data = df_new_k, x = "Clusters", kind = "count", aspect = 2)
#no of pickups in different clusters

# %%
df['hour']=df['Date/Time'].dt.hour
df
# Out:
#                  Date/Time      Lat      Lon    Base          BinnedHour  \
# 0      2014-04-01 00:11:00  40.7690 -73.9549  B02512 2014-04-01 00:00:00
# 1      2014-04-01 00:17:00  40.7267 -74.0345  B02512 2014-04-01 00:15:00
# 2      2014-04-01 00:21:00  40.7316 -73.9873  B02512 2014-04-01 00:15:00
# 3      2014-04-01 00:28:00  40.7588 -73.9776  B02512 2014-04-01 00:15:00
# 4      2014-04-01 00:33:00  40.7594 -73.9722  B02512 2014-04-01 00:30:00
# ...                    ...      ...      ...     ...                 ...
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764 2014-04-30 23:15:00
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764 2014-04-30 23:15:00
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764 2014-04-30 23:30:00
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764 2014-04-30 23:30:00
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764 2014-04-30 23:45:00
#
#               Day        Date      Time  hour
# 0         Tuesday  2014-04-01  00:00:00     0
# 1         Tuesday  2014-04-01  00:15:00     0
# 2         Tuesday  2014-04-01  00:15:00     0
# 3         Tuesday  2014-04-01  00:15:00     0
# 4         Tuesday  2014-04-01  00:30:00     0
# ...           ...         ...       ...   ...
# 564511  Wednesday  2014-04-30  23:15:00    23
# 564512  Wednesday  2014-04-30  23:15:00    23
# 564513  Wednesday  2014-04-30  23:30:00    23
# 564514  Wednesday  2014-04-30  23:30:00    23
# 564515  Wednesday  2014-04-30  23:45:00    23
#
# [564516 rows x 9 columns]

# %%
df_new_k['hour']=df_new_k['Date/Time'].dt.hour
df_new_k
# Out:
#                  Date/Time      Lat      Lon    Base          BinnedHour  \
# 0      2014-04-01 00:11:00  40.7690 -73.9549  B02512 2014-04-01 00:00:00
# 1      2014-04-01 00:17:00  40.7267 -74.0345  B02512 2014-04-01 00:15:00
# 2      2014-04-01 00:21:00  40.7316 -73.9873  B02512 2014-04-01 00:15:00
# 3      2014-04-01 00:28:00  40.7588 -73.9776  B02512 2014-04-01 00:15:00
# 4      2014-04-01 00:33:00  40.7594 -73.9722  B02512 2014-04-01 00:30:00
# ...                    ...      ...      ...     ...                 ...
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764 2014-04-30 23:15:00
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764 2014-04-30 23:15:00
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764 2014-04-30 23:30:00
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764 2014-04-30 23:30:00
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764 2014-04-30 23:45:00
#
#               Day        Date      Time  Clusters  hour
# 0         Tuesday  2014-04-01  00:00:00         4     0
# 1         Tuesday  2014-04-01  00:15:00         0     0
# 2         Tuesday  2014-04-01  00:15:00         0     0
# 3         Tuesday  2014-04-01  00:15:00         4     0
# 4         Tuesday  2014-04-01  00:30:00         4     0
# ...           ...         ...       ...       ...   ...
# 564511  Wednesday  2014-04-30  23:15:00         4    23
# 564512  Wednesday  2014-04-30  23:15:00         4    23
# 564513  Wednesday  2014-04-30  23:30:00         0    23
# 564514  Wednesday  2014-04-30  23:30:00         1    23
# 564515  Wednesday  2014-04-30  23:45:00         1    23
#
# [564516 rows x 10 columns]

# %% [markdown]
# plotting hour wise distribution of pickup counts

# %%
fig, ax = plt.subplots()
ax.hist(df_new_k['hour'])
ax.set_title("no of rides vs time of day")
ax.set_xlabel("hour of day")
ax.set_ylabel("rides")
plt.show()

# %% [markdown]
# data frames for individua clusters

# %%
df_cluster0=df_new_k[df_new_k['Clusters']==0]
df_cluster0
# Out:
#                  Date/Time      Lat      Lon    Base          BinnedHour  \
# 1      2014-04-01 00:17:00  40.7267 -74.0345  B02512 2014-04-01 00:15:00
# 2      2014-04-01 00:21:00  40.7316 -73.9873  B02512 2014-04-01 00:15:00
# 5      2014-04-01 00:33:00  40.7383 -74.0403  B02512 2014-04-01 00:30:00
# 6      2014-04-01 00:39:00  40.7223 -73.9887  B02512 2014-04-01 00:30:00
# 8      2014-04-01 00:55:00  40.7524 -73.9960  B02512 2014-04-01 00:45:00
# ...                    ...      ...      ...     ...                 ...
# 564506 2014-04-30 23:00:00  40.7316 -73.9891  B02764 2014-04-30 23:00:00
# 564507 2014-04-30 23:04:00  40.7267 -73.9937  B02764 2014-04-30 23:00:00
# 564509 2014-04-30 23:15:00  40.7420 -74.0037  B02764 2014-04-30 23:15:00
# 564510 2014-04-30 23:18:00  40.7514 -74.0066  B02764 2014-04-30 23:15:00
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764 2014-04-30 23:30:00
#
#               Day        Date      Time  Clusters  hour
# 1         Tuesday  2014-04-01  00:15:00         0     0
# 2         Tuesday  2014-04-01  00:15:00         0     0
# 5         Tuesday  2014-04-01  00:30:00         0     0
# 6         Tuesday  2014-04-01  00:30:00         0     0
# 8         Tuesday  2014-04-01  00:45:00         0     0
# ...           ...         ...       ...       ...   ...
# 564506  Wednesday  2014-04-30  23:00:00         0    23
# 564507  Wednesday  2014-04-30  23:00:00         0    23
# 564509  Wednesday  2014-04-30  23:15:00         0    23
# 564510  Wednesday  2014-04-30  23:15:00         0    23
# 564513  Wednesday  2014-04-30  23:30:00         0    23
#
# [249605 rows x 10 columns]

# %%
df_cluster1=df_new_k[df_new_k['Clusters']==1]
df_cluster2=df_new_k[df_new_k['Clusters']==2]
df_cluster3=df_new_k[df_new_k['Clusters']==3]
df_cluster4=df_new_k[df_new_k['Clusters']==4]
df_cluster5=df_new_k[df_new_k['Clusters']==5]

# %% [markdown]
# plotting hour wise distribution of pickup counts for individual clusters

# %%
fig, ax = plt.subplots()
ax.hist(df_cluster0['hour'])
ax.set_title("no of rides vs time of day of cluster 1")
ax.set_xlabel("hour of day")
ax.set_ylabel("rides")
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df_cluster1['hour'])
ax.set_title("no of rides vs time of day of cluster 2")
ax.set_xlabel("hour of day")
ax.set_ylabel("rides")
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df_cluster2['hour'])
ax.set_title("no of rides vs time of day of cluster 3")
ax.set_xlabel("hour of day")
ax.set_ylabel("rides")
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df_cluster3['hour'])
ax.set_title("no of rides vs time of day of cluster 4")
ax.set_xlabel("hour of day")
ax.set_ylabel("rides")
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df_cluster4['hour'])
ax.set_title("no of rides vs time of day of cluster 5")
ax.set_xlabel("hour of day")
ax.set_ylabel("rides")
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df_cluster5['hour'])
ax.set_title("no of rides vs time of day of cluster 6")
ax.set_xlabel("hour of day")
ax.set_ylabel("rides")
plt.show()

# %% [markdown]
# No of pickups vs the day of week

# %%
sb.catplot(data = df, x = "Day", kind = "count", aspect = 2)

# %%
weekday=['Monday','Tuesday','Wednesday','Thursday','Friday']
df_weekday=df[df['Day'].isin(weekday)]
df_weekday
# Out:
#                  Date/Time      Lat      Lon    Base          BinnedHour  \
# 0      2014-04-01 00:11:00  40.7690 -73.9549  B02512 2014-04-01 00:00:00
# 1      2014-04-01 00:17:00  40.7267 -74.0345  B02512 2014-04-01 00:15:00
# 2      2014-04-01 00:21:00  40.7316 -73.9873  B02512 2014-04-01 00:15:00
# 3      2014-04-01 00:28:00  40.7588 -73.9776  B02512 2014-04-01 00:15:00
# 4      2014-04-01 00:33:00  40.7594 -73.9722  B02512 2014-04-01 00:30:00
# ...                    ...      ...      ...     ...                 ...
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764 2014-04-30 23:15:00
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764 2014-04-30 23:15:00
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764 2014-04-30 23:30:00
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764 2014-04-30 23:30:00
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764 2014-04-30 23:45:00
#
#               Day        Date      Time  hour
# 0         Tuesday  2014-04-01  00:00:00     0
# 1         Tuesday  2014-04-01  00:15:00     0
# 2         Tuesday  2014-04-01  00:15:00     0
# 3         Tuesday  2014-04-01  00:15:00     0
# 4         Tuesday  2014-04-01  00:30:00     0
# ...           ...         ...       ...   ...
# 564511  Wednesday  2014-04-30  23:15:00    23
# 564512  Wednesday  2014-04-30  23:15:00    23
# 564513  Wednesday  2014-04-30  23:30:00    23
# 564514  Wednesday  2014-04-30  23:30:00    23
# 564515  Wednesday  2014-04-30  23:45:00    23
#
# [436047 rows x 9 columns]

# %% [markdown]
# No of pickups vs the day of week for weekdays

# %%
sb.catplot(data = df_weekday, x = "Day", kind = "count", aspect = 2)

# %% [markdown]
# Applyin K means to the uber pickup data for week days

# %%
clus_week = df_weekday[['Lat', 'Lon']]
model_week = KMeans(n_init = 'auto')
visualizer = KElbowVisualizer(model_week, k = (1, 20)) #k = 1 to 19
visualizer.fit(clus_week)#finding the optimal no of clusters elbow method
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans_week= KMeans(n_clusters = 6, random_state = 0, n_init = 'auto') #k = 6
kmeans_week.fit(clus_week)
# Out:
# KMeans(n_clusters=6, n_init='auto', random_state=0)

# %%
centroids_k_week= kmeans_week.cluster_centers_
centroids_k_week
# Out:
# array([[ 40.78708077, -73.88247176],
#        [ 40.72073347, -73.9934883 ],
#        [ 40.97768865, -73.63540686],
#        [ 40.7625969 , -73.97605309],
#        [ 40.65658884, -73.78244309],
#        [ 40.69915417, -74.20275772]])

# %%
clocation_k_week = pd.DataFrame(centroids_k_week, columns = ['Latitude', 'Longitude'])
clocation_k_week
# Out:
#     Latitude  Longitude
# 0  40.787081 -73.882472
# 1  40.720733 -73.993488
# 2  40.977689 -73.635407
# 3  40.762597 -73.976053
# 4  40.656589 -73.782443
# 5  40.699154 -74.202758

# %%
plt.scatter(clocation_k_week['Longitude'],clocation_k_week['Latitude'],  marker = "x", color = 'r', s = 200)
# locations of the centers of clusters

# %%
centroid_k_week= clocation_k_week.values.tolist()

map_k_week = folium.Map(location = [40.71600413400166, -73.98971408426613], zoom_start = 10)
for point in range(0, len(centroid_k_week)):
    folium.Marker(centroid_k_week[point], popup = centroid_k_week[point]).add_to(map_k_week)

map_k_week
#marking the centeroid points in map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a50205d3e61c85cd86118b9252990eb5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a50205d3e61c85cd86118b9252990eb5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a50205d3e61c85cd86118b9252990eb5 = L.map(
#                 &quot;map_a50205d3e61c85cd86118b9252990eb5&quot;,
#                 {
#                     center: [40.71600413400166, -73.98971408426613],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c3f65a7296eae811653e14898fbb497 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a50205d3e61c85cd86118b9252990eb5);
#
#
#             var marker_73c437cc19dddaa877df0f5fde4ba4a1 = L.marker(
#                 [40.78708076971689, -73.88247175808898],
#                 {}
#             ).addTo(map_a50205d3e61c85cd86118b9252990eb5);
#
#
#         var popup_681fb5c7b8eb29032bc95b8b2e8b5566 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bdc415c185049b3a668fbe0d1f79d935 = $(`&lt;div id=&quot;html_bdc415c185049b3a668fbe0d1f79d935&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.78708076971689, -73.88247175808898]&lt;/div&gt;`)[0];
#                 popup_681fb5c7b8eb29032bc95b8b2e8b5566.setContent(html_bdc415c185049b3a668fbe0d1f79d935);
#
#
#
#         marker_73c437cc19dddaa877df0f5fde4ba4a1.bindPopup(popup_681fb5c7b8eb29032bc95b8b2e8b5566)
#         ;
#
#
#
#
#             var marker_7f0a752d06587721e1c456933466b273 = L.marker(
#                 [40.72073347282213, -73.99348830239309],
#                 {}
#             ).addTo(map_a50205d3e61c85cd86118b9252990eb5);
#
#
#         var popup_572686c468f1c2e2457a481628612e37 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_598539509757fab10a62ec8ddf474357 = $(`&lt;div id=&quot;html_598539509757fab10a62ec8ddf474357&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.72073347282213, -73.99348830239309]&lt;/div&gt;`)[0];
#                 popup_572686c468f1c2e2457a481628612e37.setContent(html_598539509757fab10a62ec8ddf474357);
#
#
#
#         marker_7f0a752d06587721e1c456933466b273.bindPopup(popup_572686c468f1c2e2457a481628612e37)
#         ;
#
#
#
#
#             var marker_f525956445c3f78a88400967cab8c9f6 = L.marker(
#                 [40.977688654353564, -73.63540686015831],
#                 {}
#             ).addTo(map_a50205d3e61c85cd86118b9252990eb5);
#
#
#         var popup_32292f6a90097b7c7ac2217c94719209 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d4933944b2f75d69d88792ddb7c25e2e = $(`&lt;div id=&quot;html_d4933944b2f75d69d88792ddb7c25e2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.977688654353564, -73.63540686015831]&lt;/div&gt;`)[0];
#                 popup_32292f6a90097b7c7ac2217c94719209.setContent(html_d4933944b2f75d69d88792ddb7c25e2e);
#
#
#
#         marker_f525956445c3f78a88400967cab8c9f6.bindPopup(popup_32292f6a90097b7c7ac2217c94719209)
#         ;
#
#
#
#
#             var marker_ff2df61ae0b4b7502f260b538b4bbf90 = L.marker(
#                 [40.76259689929683, -73.97605308896735],
#                 {}
#             ).addTo(map_a50205d3e61c85cd86118b9252990eb5);
#
#
#         var popup_69ee4974b3fe6bd7bf7781e8bc746e56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ebde98cce9863472c57727ea5699727f = $(`&lt;div id=&quot;html_ebde98cce9863472c57727ea5699727f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.76259689929683, -73.97605308896735]&lt;/div&gt;`)[0];
#                 popup_69ee4974b3fe6bd7bf7781e8bc746e56.setContent(html_ebde98cce9863472c57727ea5699727f);
#
#
#
#         marker_ff2df61ae0b4b7502f260b538b4bbf90.bindPopup(popup_69ee4974b3fe6bd7bf7781e8bc746e56)
#         ;
#
#
#
#
#             var marker_e0476a8b34e4854d9a54bd6b77bf3c0a = L.marker(
#                 [40.656588836170805, -73.78244309238069],
#                 {}
#             ).addTo(map_a50205d3e61c85cd86118b9252990eb5);
#
#
#         var popup_f3d07ddb6a1b1fb9048be64a8f5f077b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e571d462467775bdd72d718eb91ad3d = $(`&lt;div id=&quot;html_1e571d462467775bdd72d718eb91ad3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.656588836170805, -73.78244309238069]&lt;/div&gt;`)[0];
#                 popup_f3d07ddb6a1b1fb9048be64a8f5f077b.setContent(html_1e571d462467775bdd72d718eb91ad3d);
#
#
#
#         marker_e

# %%
label_k_week = kmeans_week.labels_
label_k_week
# Out:
# array([3, 1, 1, ..., 3, 1, 1], dtype=int32)

# %%
df_new_week = df_weekday.copy()
df_new_week['Clusters'] = label_k_week
df_new_week
# Out:
#                  Date/Time      Lat      Lon    Base          BinnedHour  \
# 0      2014-04-01 00:11:00  40.7690 -73.9549  B02512 2014-04-01 00:00:00
# 1      2014-04-01 00:17:00  40.7267 -74.0345  B02512 2014-04-01 00:15:00
# 2      2014-04-01 00:21:00  40.7316 -73.9873  B02512 2014-04-01 00:15:00
# 3      2014-04-01 00:28:00  40.7588 -73.9776  B02512 2014-04-01 00:15:00
# 4      2014-04-01 00:33:00  40.7594 -73.9722  B02512 2014-04-01 00:30:00
# ...                    ...      ...      ...     ...                 ...
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764 2014-04-30 23:15:00
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764 2014-04-30 23:15:00
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764 2014-04-30 23:30:00
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764 2014-04-30 23:30:00
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764 2014-04-30 23:45:00
#
#               Day        Date      Time  hour  Clusters
# 0         Tuesday  2014-04-01  00:00:00     0         3
# 1         Tuesday  2014-04-01  00:15:00     0         1
# 2         Tuesday  2014-04-01  00:15:00     0         1
# 3         Tuesday  2014-04-01  00:15:00     0         3
# 4         Tuesday  2014-04-01  00:30:00     0         3
# ...           ...         ...       ...   ...       ...
# 564511  Wednesday  2014-04-30  23:15:00    23         3
# 564512  Wednesday  2014-04-30  23:15:00    23         3
# 564513  Wednesday  2014-04-30  23:30:00    23         3
# 564514  Wednesday  2014-04-30  23:30:00    23         1
# 564515  Wednesday  2014-04-30  23:45:00    23         1
#
# [436047 rows x 10 columns]

# %%
ymeans=np.copy(df_new_week['Clusters'] )
ymeans
# Out:
# array([3, 1, 1, ..., 3, 1, 1], dtype=int32)

# %%
fig,ax=plt.subplots()
ax.scatter(df_weekday['Lon'], df_weekday['Lat'], c=ymeans, s=50, cmap='viridis')
ax.set_xlabel("Longitude")
ax.set_ylabel("Lattitude")
plt.show()
# scatter plot of the clusters

# %% [markdown]
# no of pickups in different clusters for weekdays data

# %%
sb.catplot(data = df_new_week, x = "Clusters", kind = "count", aspect = 2)

# %%
fig, ax = plt.subplots()
ax.hist(df_new_week['hour'])
ax.set_title("no of rides vs time of day for weekdays")
ax.set_xlabel("hour of day")
ax.set_ylabel("rides")
plt.show()

# %% [markdown]
# applying k means to weekend data

# %%
weekend=['Saturday','Sunday']
df_weekend=df[df['Day'].isin(weekend)]
df_weekend
# Out:
#                  Date/Time      Lat      Lon    Base          BinnedHour  \
# 5656   2014-04-05 00:00:00  40.7690 -73.9825  B02512 2014-04-05 00:00:00
# 5657   2014-04-05 00:00:00  40.7594 -73.9641  B02512 2014-04-05 00:00:00
# 5658   2014-04-05 00:01:00  40.7113 -74.0173  B02512 2014-04-05 00:00:00
# 5659   2014-04-05 00:02:00  40.8060 -73.9652  B02512 2014-04-05 00:00:00
# 5660   2014-04-05 00:04:00  40.7211 -74.0042  B02512 2014-04-05 00:00:00
# ...                    ...      ...      ...     ...                 ...
# 563273 2014-04-27 22:59:00  40.7741 -73.8725  B02764 2014-04-27 22:45:00
# 563274 2014-04-27 23:23:00  40.7782 -73.9625  B02764 2014-04-27 23:15:00
# 563275 2014-04-27 23:33:00  40.6449 -73.7823  B02764 2014-04-27 23:30:00
# 563276 2014-04-27 23:35:00  40.7278 -73.9822  B02764 2014-04-27 23:30:00
# 563277 2014-04-27 23:41:00  40.6879 -74.1813  B02764 2014-04-27 23:30:00
#
#              Day        Date      Time  hour
# 5656    Saturday  2014-04-05  00:00:00     0
# 5657    Saturday  2014-04-05  00:00:00     0
# 5658    Saturday  2014-04-05  00:00:00     0
# 5659    Saturday  2014-04-05  00:00:00     0
# 5660    Saturday  2014-04-05  00:00:00     0
# ...          ...         ...       ...   ...
# 563273    Sunday  2014-04-27  22:45:00    22
# 563274    Sunday  2014-04-27  23:15:00    23
# 563275    Sunday  2014-04-27  23:30:00    23
# 563276    Sunday  2014-04-27  23:30:00    23
# 563277    Sunday  2014-04-27  23:30:00    23
#
# [128469 rows x 9 columns]

# %%
sb.catplot(data = df_weekend, x = "Day", kind = "count", aspect = 2)

# %%
clus_end = df_weekend[['Lat', 'Lon']]
model_end = KMeans(n_init = 'auto')
visualizer = KElbowVisualizer(model_end, k = (1, 20)) #k = 1 to 19
visualizer.fit(clus_end)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans_end= KMeans(n_clusters = 6, random_state = 0, n_init = 'auto') #k = 6
kmeans_end.fit(clus_end)
# Out:
# KMeans(n_clusters=6, n_init='auto', random_state=0)

# %%
centroids_k_end= kmeans_end.cluster_centers_
centroids_k_end
# Out:
# array([[ 40.73306218, -73.99766619],
#        [ 40.67043455, -73.78183119],
#        [ 40.77140266, -73.96054573],
#        [ 40.70511396, -74.19737426],
#        [ 40.68926254, -73.96382839],
#        [ 40.90705233, -73.82673432]])

# %%
clocation_k_end = pd.DataFrame(centroids_k_end, columns = ['Latitude', 'Longitude'])
clocation_k_end
# Out:
#     Latitude  Longitude
# 0  40.733062 -73.997666
# 1  40.670435 -73.781831
# 2  40.771403 -73.960546
# 3  40.705114 -74.197374
# 4  40.689263 -73.963828
# 5  40.907052 -73.826734

# %%
plt.scatter(clocation_k_end['Longitude'], clocation_k_end['Latitude'], marker = "x", color = 'r', s = 200)

# %%
centroid_k_end= clocation_k_end.values.tolist()

map_k_end = folium.Map(location = [40.71600413400166, -73.98971408426613], zoom_start = 10)
for point in range(0, len(centroid_k_end)):
    folium.Marker(centroid_k_end[point], popup = centroid_k_end[point]).add_to(map_k_end)

map_k_end
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_857fc9f487edfa88285b6c68776e8445 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_857fc9f487edfa88285b6c68776e8445&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_857fc9f487edfa88285b6c68776e8445 = L.map(
#                 &quot;map_857fc9f487edfa88285b6c68776e8445&quot;,
#                 {
#                     center: [40.71600413400166, -73.98971408426613],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6138e56e298f3e894d44f78e5e9c545b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_857fc9f487edfa88285b6c68776e8445);
#
#
#             var marker_791e138297fc76e8f7ba71ed6119a851 = L.marker(
#                 [40.733062175116046, -73.99766619392491],
#                 {}
#             ).addTo(map_857fc9f487edfa88285b6c68776e8445);
#
#
#         var popup_beccea88b233f885a926bdc28c8a0dcc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad5ca304c214b460e7381491ad4336b9 = $(`&lt;div id=&quot;html_ad5ca304c214b460e7381491ad4336b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.733062175116046, -73.99766619392491]&lt;/div&gt;`)[0];
#                 popup_beccea88b233f885a926bdc28c8a0dcc.setContent(html_ad5ca304c214b460e7381491ad4336b9);
#
#
#
#         marker_791e138297fc76e8f7ba71ed6119a851.bindPopup(popup_beccea88b233f885a926bdc28c8a0dcc)
#         ;
#
#
#
#
#             var marker_aca9a61cd29ff63b039cd3f19d19b68c = L.marker(
#                 [40.6704345471522, -73.78183118580766],
#                 {}
#             ).addTo(map_857fc9f487edfa88285b6c68776e8445);
#
#
#         var popup_80f96fb1a80bd7365ebea487b6879b94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_261405bd38d422c6fba816f689dc9e40 = $(`&lt;div id=&quot;html_261405bd38d422c6fba816f689dc9e40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.6704345471522, -73.78183118580766]&lt;/div&gt;`)[0];
#                 popup_80f96fb1a80bd7365ebea487b6879b94.setContent(html_261405bd38d422c6fba816f689dc9e40);
#
#
#
#         marker_aca9a61cd29ff63b039cd3f19d19b68c.bindPopup(popup_80f96fb1a80bd7365ebea487b6879b94)
#         ;
#
#
#
#
#             var marker_f166917a4cca0bb740950b8c27a63db9 = L.marker(
#                 [40.77140265504603, -73.96054572739604],
#                 {}
#             ).addTo(map_857fc9f487edfa88285b6c68776e8445);
#
#
#         var popup_725b5d4a5c0828380a96c4df90b7f73a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_073c2567d81d2fc0dc60c10f231ebd2a = $(`&lt;div id=&quot;html_073c2567d81d2fc0dc60c10f231ebd2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.77140265504603, -73.96054572739604]&lt;/div&gt;`)[0];
#                 popup_725b5d4a5c0828380a96c4df90b7f73a.setContent(html_073c2567d81d2fc0dc60c10f231ebd2a);
#
#
#
#         marker_f166917a4cca0bb740950b8c27a63db9.bindPopup(popup_725b5d4a5c0828380a96c4df90b7f73a)
#         ;
#
#
#
#
#             var marker_dcec8cb94150b01b435080350cb2b29e = L.marker(
#                 [40.70511396160558, -74.1973742582897],
#                 {}
#             ).addTo(map_857fc9f487edfa88285b6c68776e8445);
#
#
#         var popup_6720841d7376290386e5ba899c8b548c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5dd94dd3289ee63b46ef4bd4a4101bda = $(`&lt;div id=&quot;html_5dd94dd3289ee63b46ef4bd4a4101bda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.70511396160558, -74.1973742582897]&lt;/div&gt;`)[0];
#                 popup_6720841d7376290386e5ba899c8b548c.setContent(html_5dd94dd3289ee63b46ef4bd4a4101bda);
#
#
#
#         marker_dcec8cb94150b01b435080350cb2b29e.bindPopup(popup_6720841d7376290386e5ba899c8b548c)
#         ;
#
#
#
#
#             var marker_82aa77ac347de108844cc46f2f0d09ad = L.marker(
#                 [40.68926254400375, -73.96382839239615],
#                 {}
#             ).addTo(map_857fc9f487edfa88285b6c68776e8445);
#
#
#         var popup_5bf44c1422cd5f02c5a279d7dec2a017 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b7dcbcf1788914b4e0c27b8ba85ec2d = $(`&lt;div id=&quot;html_4b7dcbcf1788914b4e0c27b8ba85ec2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.68926254400375, -73.96382839239615]&lt;/div&gt;`)[0];
#                 popup_5bf44c1422cd5f02c5a279d7dec2a017.setContent(html_4b7dcbcf1788914b4e0c27b8ba85ec2d);
#
#
#
#         marker_82aa77a

# %%
label_k_end = kmeans_end.labels_
label_k_end
# Out:
# array([2, 2, 0, ..., 1, 0, 3], dtype=int32)

# %%
df_new_end = df_weekend.copy()
df_new_end['Clusters'] = label_k_end
df_new_end
# Out:
#                  Date/Time      Lat      Lon    Base          BinnedHour  \
# 5656   2014-04-05 00:00:00  40.7690 -73.9825  B02512 2014-04-05 00:00:00
# 5657   2014-04-05 00:00:00  40.7594 -73.9641  B02512 2014-04-05 00:00:00
# 5658   2014-04-05 00:01:00  40.7113 -74.0173  B02512 2014-04-05 00:00:00
# 5659   2014-04-05 00:02:00  40.8060 -73.9652  B02512 2014-04-05 00:00:00
# 5660   2014-04-05 00:04:00  40.7211 -74.0042  B02512 2014-04-05 00:00:00
# ...                    ...      ...      ...     ...                 ...
# 563273 2014-04-27 22:59:00  40.7741 -73.8725  B02764 2014-04-27 22:45:00
# 563274 2014-04-27 23:23:00  40.7782 -73.9625  B02764 2014-04-27 23:15:00
# 563275 2014-04-27 23:33:00  40.6449 -73.7823  B02764 2014-04-27 23:30:00
# 563276 2014-04-27 23:35:00  40.7278 -73.9822  B02764 2014-04-27 23:30:00
# 563277 2014-04-27 23:41:00  40.6879 -74.1813  B02764 2014-04-27 23:30:00
#
#              Day        Date      Time  hour  Clusters
# 5656    Saturday  2014-04-05  00:00:00     0         2
# 5657    Saturday  2014-04-05  00:00:00     0         2
# 5658    Saturday  2014-04-05  00:00:00     0         0
# 5659    Saturday  2014-04-05  00:00:00     0         2
# 5660    Saturday  2014-04-05  00:00:00     0         0
# ...          ...         ...       ...   ...       ...
# 563273    Sunday  2014-04-27  22:45:00    22         2
# 563274    Sunday  2014-04-27  23:15:00    23         2
# 563275    Sunday  2014-04-27  23:30:00    23         1
# 563276    Sunday  2014-04-27  23:30:00    23         0
# 563277    Sunday  2014-04-27  23:30:00    23         3
#
# [128469 rows x 10 columns]

# %%
ymeans=np.copy(df_new_end['Clusters'] )
ymeans
# Out:
# array([2, 2, 0, ..., 1, 0, 3], dtype=int32)

# %%
fig,ax=plt.subplots()
ax.scatter(df_weekend['Lon'],df_weekend['Lat'],  c=ymeans, s=50, cmap='viridis')
ax.set_xlabel("Longitude")
ax.set_ylabel("Lattitude")
plt.show()

# %% [markdown]
# no of pickups in different clusters for weekend data

# %%
sb.catplot(data = df_new_end, x = "Clusters", kind = "count", aspect = 2)

# %%
fig, ax = plt.subplots()
ax.hist(df_new_end['hour'])
ax.set_title("no of rides vs time of day for weekends")
ax.set_xlabel("hour of day")
ax.set_ylabel("rides")
plt.show()
